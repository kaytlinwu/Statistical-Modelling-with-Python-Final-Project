# %% [markdown]
# Join the data from Part 1 with the data from Part 2 to create a new dataframe.

# %%
#Import libraries 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#import data: miami_bikes.csv to the notebook.
#Preview dataframes with df.head()

miami_bikes = pd.read_csv('../data/miami_bikes.csv')
miami_bikes.head()

foursquare_data = pd.read_csv('../data/foursquare_data.csv')
foursquare_data.head()
# Out:
#                             Name       Locality  Popularity  Price  Rating  \
# 0                  Bombay Darbar          Miami    0.977682    2.0     9.0
# 1       Jaguar Ceviche Spoon Bar          Miami    0.973000    2.0     8.6
# 2  Mister O1 Extraordinary Pizza          Miami    0.974360    1.0     8.2
# 3              Le Pain Quotidien          Miami    0.952608    1.0     8.6
# 4               Harry's Pizzeria  Coconut Grove    0.953315    2.0     8.4
#
#                    Category1                  Category2            Category3  \
# 0          Indian Restaurant  Food and Beverage Service  Dining and Drinking
# 1  Latin American Restaurant         Seafood Restaurant  Dining and Drinking
# 2                   Pizzeria                        NaN                  NaN
# 3                       Café                        NaN                  NaN
# 4    New American Restaurant                   Pizzeria                  NaN
#
#     Latitude  Longitude Bike_Station_Coordinates
# 0  25.729251 -80.240721     25.729275,-80.241581
# 1  25.728360 -80.242803     25.729275,-80.241581
# 2  25.728740 -80.242009     25.729275,-80.241581
# 3  25.727386 -80.242620     25.729275,-80.241581
# 4  25.727746 -80.242118     25.729275,-80.241581

# %%
#Iterate through each bike station from miami_bikes.csv
Bike_Station_Coordinates = []
# Iterate through rows using iterrows()

for index, row in miami_bikes.iterrows():
    latitude = row['latitude']
    longitude = row['longitude']
    Bike_Station_Coordinates.append((latitude, longitude))

# %%
#add bike station coordinates to miami_bikes
miami_bikes["station_coordinates"] = Bike_Station_Coordinates

# %%
miami_bikes.head()
# Out:
#     latitude  longitude  bikes      station_coordinates
# 0  25.729275 -80.241581      3  (25.729275, -80.241581)
# 1  25.732522 -80.233244      3  (25.732522, -80.233244)
# 2  25.751100 -80.202641      4    (25.7511, -80.202641)
# 3  25.760082 -80.196217      2  (25.760082, -80.196217)
# 4  25.761884 -80.193101      1  (25.761884, -80.193101)

# %%
#Print how the dataframe looks when filtering for 1 coordinate
print(miami_bikes.loc[miami_bikes['station_coordinates'] == (25.729275,-80.241581)])
# Out:
#     latitude  longitude  bikes      station_coordinates
# 0  25.729275 -80.241581      3  (25.729275, -80.241581)

# %%
#join foursquare_data with miami_bikes
#Iterate through each row from foursquare_data.csv
free_bikes= []

# Add an empty column in the foursquare dataframe
foursquare_data['bikes'] = None

for index, row in foursquare_data.iterrows():
    bike_coordinates = row['Bike_Station_Coordinates']
    latitude, longitude = bike_coordinates.split(',')
    formatted_value = (float(latitude), float(longitude))
    bikes = miami_bikes.loc[miami_bikes['station_coordinates'] == formatted_value]['bikes'].values[0]
    
    # update the df at the current index
    foursquare_data.at[index, 'bikes'] = bikes
#     free_bikes.append(bikes)

foursquare_data.head()
# Out:
#                             Name       Locality  Popularity  Price  Rating  \
# 0                  Bombay Darbar          Miami    0.977682    2.0     9.0
# 1       Jaguar Ceviche Spoon Bar          Miami    0.973000    2.0     8.6
# 2  Mister O1 Extraordinary Pizza          Miami    0.974360    1.0     8.2
# 3              Le Pain Quotidien          Miami    0.952608    1.0     8.6
# 4               Harry's Pizzeria  Coconut Grove    0.953315    2.0     8.4
#
#                    Category1                  Category2            Category3  \
# 0          Indian Restaurant  Food and Beverage Service  Dining and Drinking
# 1  Latin American Restaurant         Seafood Restaurant  Dining and Drinking
# 2                   Pizzeria                        NaN                  NaN
# 3                       Café                        NaN                  NaN
# 4    New American Restaurant                   Pizzeria                  NaN
#
#     Latitude  Longitude Bike_Station_Coordinates bikes
# 0  25.729251 -80.240721     25.729275,-80.241581     3
# 1  25.728360 -80.242803     25.729275,-80.241581     3
# 2  25.728740 -80.242009     25.729275,-80.241581     3
# 3  25.727386 -80.242620     25.729275,-80.241581     3
# 4  25.727746 -80.242118     25.729275,-80.241581     3

# %%
#QA test: Check to ensure that the number of bikes matches the station that was provided on miami_bikes.csv
#Expecting 20 bikes
station1 = foursquare_data.loc[foursquare_data['Bike_Station_Coordinates']== '25.765327,-80.131324']
station1
# Out:
#                                      Name     Locality  Popularity  Price  \
# 436       Smith & Wollensky - Miami Beach  Miami Beach    0.985989    3.0
# 437                     The Lobster Shack  Miami Beach    0.990337    3.0
# 438                               Carbone  Miami Beach    0.989274    2.0
# 439                           Nikki Beach  Miami Beach    0.998889    3.0
# 440                      Joe's Stone Crab  Miami Beach    0.994782    4.0
# 441                          Call Me Gaby  Miami Beach    0.969127    2.0
# 442                 Santorini by Georgios  Miami Beach    0.982462    2.0
# 443                         Prime Italian  Miami Beach    0.988936    4.0
# 444  Estiatorio Milos by Costas Spiliadis  Miami Beach    0.973186    3.0
# 445                       Joe's Take-Away  Miami Beach    0.982849    2.0
#
#      Rating            Category1                  Category2  \
# 436     8.7   Seafood Restaurant                 Steakhouse
# 437     8.6   Seafood Restaurant                        NaN
# 438     9.0   Italian Restaurant                        NaN
# 439     8.6           Night Club        American Restaurant
# 440     9.0  American Restaurant         Seafood Restaurant
# 441     9.0             Pizzeria         Italian Restaurant
# 442     8.4     Greek Restaurant  Middle Eastern Restaurant
# 443     8.5   Italian Restaurant                        NaN
# 444     9.0     Greek Restaurant   Mediterranean Restaurant
# 445     8.5   Seafood Restaurant                        NaN
#
#                Category3   Latitude  Longitude Bike_Station_Coordinates bikes
# 436                  NaN  25.765904 -80.134019     25.765327,-80.131324    20
# 437                  NaN  25.768183 -80.132688     25.765327,-80.131324    20
# 438                  NaN  25.769431 -80.133764     25.765327,-80.131324    20
# 439  Japanese Restaurant  25.769090 -80.132260     25.765327,-80.131324    20
# 440                  NaN  25.768798 -80.135086     25.765327,-80.131324    20
# 441                  NaN  25.768881 -80.135634     25.765327,-80.131324    20
# 442   Seafood Restaurant  25.769695 -80.132546     25.765327,-80.131324    20
# 443                  NaN  25.769675 -80.132838     25.765327,-80.131324    20
# 444   Seafood Restaurant  25.769718 -80.135683     25.765327,-80.131324    20
# 445                  NaN  25.768569 -80.135094     25.765327,-80.131324    20

# %%
#drop unwanted columns in combined dataframe
#drop latitude and longitude of point of interest/business

combined_data = foursquare_data.drop(columns = ['Latitude', 'Longitude'])

# %%
#Make a new column that indicates what the category is for each row (only looking at the main category)

type_list = ['Restaurant','Café','Coffee', 'Bar','College and University','Bakery']
place_type = []
excluded_categories = set()

for index, row in combined_data.iterrows():
    match1 = next((x for x in type_list if x in str(row['Category1'])), None)
    match2 = next((x for x in type_list if x in str(row['Category2'])), None)
    match3 = next((x for x in type_list if x in str(row['Category3'])), None)
    final_match = match1 or match2 or match3
    
    if final_match == 'Coffee':
        final_match = 'Café'

    if final_match:
        place_type.append(final_match)
    else:
        excluded_categories.add(row['Category1'])
        excluded_categories.add(row['Category2'])
        excluded_categories.add(row['Category3'])
        place_type.append(None)

#Take a look at categories that were excluded
print("Excluded categories are:")
print(excluded_categories)
# Out:
# Excluded categories are:
# {'Deli', 'Steakhouse', 'Burger Joint', 'Ice Cream Parlor', 'BBQ Joint', nan, 'Fried Chicken Joint', 'Bistro', 'Pizzeria', 'Dining and Drinking'}

# %%
# #Add place_type to dataframe
combined_data['Place_Type'] = place_type

#See if Place_Type looks correct in dataframe
combined_data.head()
# Out:
#                             Name       Locality  Popularity  Price  Rating  \
# 0                  Bombay Darbar          Miami    0.977682    2.0     9.0
# 1       Jaguar Ceviche Spoon Bar          Miami    0.973000    2.0     8.6
# 2  Mister O1 Extraordinary Pizza          Miami    0.974360    1.0     8.2
# 3              Le Pain Quotidien          Miami    0.952608    1.0     8.6
# 4               Harry's Pizzeria  Coconut Grove    0.953315    2.0     8.4
#
#                    Category1                  Category2            Category3  \
# 0          Indian Restaurant  Food and Beverage Service  Dining and Drinking
# 1  Latin American Restaurant         Seafood Restaurant  Dining and Drinking
# 2                   Pizzeria                        NaN                  NaN
# 3                       Café                        NaN                  NaN
# 4    New American Restaurant                   Pizzeria                  NaN
#
#   Bike_Station_Coordinates bikes  Place_Type
# 0     25.729275,-80.241581     3  Restaurant
# 1     25.729275,-80.241581     3  Restaurant
# 2     25.729275,-80.241581     3        None
# 3     25.729275,-80.241581     3        Café
# 4     25.729275,-80.241581     3  Restaurant

# %%
#Drop all category columns and preview new dataframe
combined_data = combined_data.drop(columns= ['Category1', 'Category2', 'Category3'])

combined_data.head()
# Out:
#                             Name       Locality  Popularity  Price  Rating  \
# 0                  Bombay Darbar          Miami    0.977682    2.0     9.0
# 1       Jaguar Ceviche Spoon Bar          Miami    0.973000    2.0     8.6
# 2  Mister O1 Extraordinary Pizza          Miami    0.974360    1.0     8.2
# 3              Le Pain Quotidien          Miami    0.952608    1.0     8.6
# 4               Harry's Pizzeria  Coconut Grove    0.953315    2.0     8.4
#
#   Bike_Station_Coordinates bikes  Place_Type
# 0     25.729275,-80.241581     3  Restaurant
# 1     25.729275,-80.241581     3  Restaurant
# 2     25.729275,-80.241581     3        None
# 3     25.729275,-80.241581     3        Café
# 4     25.729275,-80.241581     3  Restaurant

# %%
#Remove rows that have Null for Place_Type. They will not be used in the analysis

combined_data_clean = combined_data.dropna(subset=['Place_Type'])

# %%
#Make a list of remaining columns. 
print(combined_data_clean.columns)
print(combined_data_clean.dtypes)

#bikes column need to be changed into an interger
# Out:
# Index(['Name', 'Locality', 'Popularity', 'Price', 'Rating',
#        'Bike_Station_Coordinates', 'bikes', 'Place_Type'],
#       dtype='object')
# Name                         object
# Locality                     object
# Popularity                  float64
# Price                       float64
# Rating                      float64
# Bike_Station_Coordinates     object
# bikes                        object
# Place_Type                   object
# dtype: object

# %%
#Change bikes datatype to interger
combined_data_clean = combined_data_clean.astype({"bikes": int})

#confirm data type has been changed
print(combined_data_clean.dtypes)
# Out:
# Name                         object
# Locality                     object
# Popularity                  float64
# Price                       float64
# Rating                      float64
# Bike_Station_Coordinates     object
# bikes                         int32
# Place_Type                   object
# dtype: object

# %%
#Within numerical columns, see how many NULL values are present
combined_data_clean.isna().sum()
# Out:
# Name                         0
# Locality                     0
# Popularity                   9
# Price                       72
# Rating                      31
# Bike_Station_Coordinates     0
# bikes                        0
# Place_Type                   0
# dtype: int64

# %%
#How many are Univerisities with no price
print(combined_data_clean[combined_data_clean['Place_Type'].str.contains('College')])
# Out:
#                                    Name     Locality  Popularity  Price  \
# 21    Universidad Del Caribe of Florida        Miami         NaN    NaN
# 24                    Unicaribe College        Miami         NaN    NaN
# 25                   Miami Dade College        Miami         NaN    NaN
# 373                  Breakthrough Miami        Miami    0.088511    NaN
# 375                      Seawalls Class        Miami    0.554760    NaN
# 1302                University of Miami  Miami Beach         NaN    NaN
#
#       Rating Bike_Station_Coordinates  bikes              Place_Type
# 21       NaN       25.7511,-80.202641      4  College and University
# 24       NaN       25.7511,-80.202641      4  College and University
# 25       NaN       25.7511,-80.202641      4  College and University
# 373      NaN     25.747976,-80.210054      3  College and University
# 375      NaN     25.747976,-80.210054      3  College and University
# 1302     NaN      25.852079,-80.13755     13  College and University

# %%
#Store colleges in variable to add back into dataframe. 
university_data = combined_data_clean[combined_data_clean['Place_Type'].str.contains('College')]

# %%
#Look at rows that have NULL value in column Rating
print(combined_data_clean[combined_data_clean['Rating'].isnull()])
# Out:
#                                               Name            Locality  \
# 21               Universidad Del Caribe of Florida               Miami
# 22                                       Cure Cafe               Miami
# 23    Le Café At The Santa Maria Condo On Brickell               Miami
# 24                               Unicaribe College               Miami
# 25                              Miami Dade College               Miami
# 110                                 Taste of Miami               Miami
# 112                                     Gordo Cafe               Miami
# 113                               Fritanga Tiscapa               Miami
# 114                   La Valentina Mexican Kitchen               Miami
# 115                                   Man vs Fries               Miami
# 373                             Breakthrough Miami               Miami
# 374                                El Café de Rigo               Miami
# 375                                 Seawalls Class               Miami
# 1250                                Blu Gin Lounge         Miami Beach
# 1252                             Arlen Beach House         Miami Beach
# 1253                        Morgans at Arlen Beach         Miami Beach
# 1297                              Chocolate y Cafe         Miami Beach
# 1298                                    Petralunga   North Bay Village
# 1299                                    Bodegon 71         Miami Beach
# 1300                                      C J Cafe   North Bay Village
# 1301                              Bob's Your Uncle         Miami Beach
# 1302                           University of Miami         Miami Beach
# 1303                    7tyone Restaurant & Coffee         Miami Beach
# 1345                            Divine Enterprises         Miami Beach
# 1346                                    Surfnsides            Surfside
# 1396                         Mestizo Gastro Fusion  Bay Harbor Islands
# 1424                              Chocolate y Cafe         Miami Beach
# 1425                                    Bodegon 71         Miami Beach
# 1426                              Bob's Your Uncle         Miami Beach
# 1592                                    Petralunga   North Bay Village
# 1593                                      C J Cafe   North Bay Village
#
#       Popularity  Price  Rating Bike_Station_Coordinates  bikes  \
# 21           NaN    NaN     NaN       25.7511,-80.202641      4
# 22      0.919812    1.0     NaN       25.7511,-80.202641      4
# 23      0.927799    1.0     NaN       25.7511,-80.202641      4
# 24           NaN    NaN     NaN       25.7511,-80.202641      4
# 25           NaN    NaN     NaN       25.7511,-80.202641      4
# 110     0.874028    2.0     NaN     25.779881,-80.218424      3
# 112     0.692713    1.0     NaN     25.779881,-80.218424      3
# 113     0.911101    2.0     NaN     25.779881,-80.218424      3
# 114     0.985086    1.0     NaN     25.779881,-80.218424      3
# 115          NaN    NaN     NaN     25.779881,-80.218424      3
# 373     0.088511    NaN     NaN     25.747976,-80.210054      3
# 374     0.917391    1.0     NaN     25.747976,-80.210054      3
# 375     0.554760    NaN     NaN     25.747976,-80.210054      3
# 1250    0.954971    3.0     NaN     25.830375,-80.122238      5
# 1252    0.930428    2.0     NaN     25.830375,-80.122238      5
# 1253         NaN    NaN     NaN     25.830375,-80.122238      5
# 1297    0.953039    1.0     NaN      25.852079,-80.13755     13
# 1298    0.958580    2.0     NaN      25.852079,-80.13755     13
# 1299    0.862450    2.0     NaN      25.852079,-80.13755     13
# 1300    0.891519    1.0     NaN      25.852079,-80.13755     13
# 1301    0.966905    3.0     NaN      25.852079,-80.13755     13
# 1302         NaN    NaN     NaN      25.852079,-80.13755     13
# 1303         NaN    NaN     NaN      25.852079,-80.13755     13
# 1345         NaN    NaN     NaN     25.873098,-80.122093      0
# 1346         NaN    NaN     NaN     25.873098,-80.122093      0
# 1396    0.984694    2.0     NaN     25.893302,-80.132423      9
# 1424    0.953039    1.0     NaN     25.854495,-80.132502     13
# 1425    0.862450    2.0     NaN     25.854495,-80.132502     13
# 1426    0.966905    3.0     NaN     25.854495,-80.132502     13
# 1592    0.958580    2.0     NaN   25.8561371,-80.1447683      2
# 1593    0.891519    1.0     NaN   25.8561371,-80.1447683      2
#
#                   Place_Type
# 21    College and University
# 22                      Café
# 23                      Café
# 24    College and University
# 25    College and University
# 110               Restaurant
# 112                     Café
# 113               Restaurant
# 114               Restaurant
# 115               Restaurant
# 373   College and University
# 374                     Café
# 375   College and University
# 1250              Restaurant
# 1252              Restaurant
# 1253              Restaurant
# 1297                    Café
# 1298              Restaurant
# 1299                     Bar
# 1300                    Café
# 1301                     Bar
# 1302  College and University
# 1303                    Café
# 1345                    Café
# 1346              Restaurant
# 1396              Restaurant
# 1424                    Café
# 1425                     Bar
# 1426                     Bar
# 1592              Restaurant
# 1593                    Café

# %%
#Look at rows that have NULL value in column Popularity                   
print(combined_data_clean[combined_data_clean['Popularity'].isnull()])
# Out:
#                                    Name     Locality  Popularity  Price  \
# 21    Universidad Del Caribe of Florida        Miami         NaN    NaN
# 24                    Unicaribe College        Miami         NaN    NaN
# 25                   Miami Dade College        Miami         NaN    NaN
# 115                        Man vs Fries        Miami         NaN    NaN
# 1253             Morgans at Arlen Beach  Miami Beach         NaN    NaN
# 1302                University of Miami  Miami Beach         NaN    NaN
# 1303         7tyone Restaurant & Coffee  Miami Beach         NaN    NaN
# 1345                 Divine Enterprises  Miami Beach         NaN    NaN
# 1346                         Surfnsides     Surfside         NaN    NaN
#
#       Rating Bike_Station_Coordinates  bikes              Place_Type
# 21       NaN       25.7511,-80.202641      4  College and University
# 24       NaN       25.7511,-80.202641      4  College and University
# 25       NaN       25.7511,-80.202641      4  College and University
# 115      NaN     25.779881,-80.218424      3              Restaurant
# 1253     NaN     25.830375,-80.122238      5              Restaurant
# 1302     NaN      25.852079,-80.13755     13  College and University
# 1303     NaN      25.852079,-80.13755     13                    Café
# 1345     NaN     25.873098,-80.122093      0                    Café
# 1346     NaN     25.873098,-80.122093      0              Restaurant

# %%
combined_data_clean = combined_data_clean.dropna(subset=['Popularity','Price','Rating'])
combined_data_clean.isna().sum()
# Out:
# Name                        0
# Locality                    0
# Popularity                  0
# Price                       0
# Rating                      0
# Bike_Station_Coordinates    0
# bikes                       0
# Place_Type                  0
# dtype: int64

# %%
#add back universities into final dataframe
finaldf = pd.concat([combined_data_clean, university_data])

# %%
#Remove any duplicated columns that may have resulted when combining combined_data_clean and university_data
finaldf = finaldf[~finaldf.index.duplicated()]

# %% [markdown]
# Provide a visualization that you used as part of your EDA process. Explain the initial pattern or relationship you discoved through this visualization.

# %%
#Visualize data to see if there are any outliers within the dataset
sns.pairplot(finaldf, hue="Place_Type",diag_kind="hist")

#Looks like there may be a few outliers

# %%
#quick overview of statistics found in dataframe
finaldf.describe()
# Out:
#         Popularity        Price       Rating        bikes
# count  1452.000000  1450.000000  1450.000000  1456.000000
# mean      0.972923     2.164828     8.587793     5.677198
# std       0.032839     0.895355     0.487917     4.777833
# min       0.088511     1.000000     5.900000     0.000000
# 25%       0.967742     2.000000     8.300000     2.000000
# 50%       0.976423     2.000000     8.600000     5.000000
# 75%       0.986907     3.000000     9.000000     8.000000
# max       0.999565     4.000000     9.400000    25.000000

# %% [markdown]
# *****Findings from EDA Process:
#
# #popularity min is very low
# #min rating low (skewed to the left)
# #bikes max (skewed to the right)

# %% [markdown]
# # Database

# %% [markdown]
# Put all your results in an SQLite3 database (remember, SQLite stores its databases as files in your local machine - make sure to create your database in your project's data/ directory!)

# %%
#import libraries
import sqlite3 as sq
import pandas as pd
from sqlalchemy import create_engine

# %%
#Writing df to sqlite

table_name = "miami_bikes"

sql_data = '..\data\miamibikes.sqlite' # creates a database called miamibikes in the data directory

conn = sq.connect(sql_data)

finaldf.to_sql(table_name,conn, if_exists='replace',index=False)
conn.close()

# %% [markdown]
# Look at the data before and after the join to validate your data.

# %%
print(finaldf.shape)

#Inspected data in VS Code and all data look complete
#Total record count is correct. n = 1456 rows, 8 columns returned
#Matches dimensions returned by finaldf.shape
# Out:
# (1456, 8)
